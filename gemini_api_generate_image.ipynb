# %% [markdown]
# <a href="https://colab.research.google.com/github/koji/AI-Colab-Notebooks/blob/main/gemini_api_generate_image.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# install package
# !pip install google-genai

# %%
from google.colab import userdata
GOOGLE_API_KEY = userdata.get("GOOGLE_API_KEY")

# %%
from google import genai
client = genai.Client(api_key=GOOGLE_API_KEY)

# %%
from google import genai
from google.genai import types
from PIL import Image
from io import BytesIO


response = client.models.generate_content(
    model="models/gemini-2.0-flash-exp",
    contents = ('Hi, can you create a 3d rendered image of a pig '
            'with wings and a top hat flying over a happy '
            'futuristic scifi city with lots of greenery?'),
    config=types.GenerateContentConfig(response_modalities=['Text', 'Image'])
)


for part in response.candidates[0].content.parts:
  if part.text is not None:
    print(part.text)
  elif part.inline_data is not None:
    image = Image.open(BytesIO(part.inline_data.data))
    display(image)
# Out:
# I will generate a 3D rendered image of a cheerful pink pig wearing a distinguished grey top hat and a pair of feathery white wings. The pig will be soaring through the air above a brightly colored, utopian futuristic city filled with sleek, rounded buildings and abundant lush green vegetation on rooftops and integrated into the architecture. The overall mood will be lighthearted and whimsical.
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1024x1024>
